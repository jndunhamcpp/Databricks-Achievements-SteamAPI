# %%
# ==============================
# SteamSpy Pipeline Orchestration
# ===============================

# 1. Setup schemas

# 2. Bronze ingestion

# 3. Silver transformation

# 4. Gold transformations

# 5. View creation

print("Pipeline run complete")
